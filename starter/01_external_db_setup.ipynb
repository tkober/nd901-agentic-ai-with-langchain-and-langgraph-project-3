# %%
from datetime import datetime, timedelta
import json
import uuid
import random 
from sqlalchemy import create_engine

from utils import reset_db, get_session, model_to_dict
from data.models import cultpass

# %% [markdown]
# # Udahub Accounts

# %% [markdown]
# ## Cultpass Database

# %% [markdown]
# **Init DB**

# %%
cultpass_db = "data/external/cultpass.db"

# %%
reset_db(cultpass_db)
# Out:
# ✅ Removed existing data/external/cultpass.db
# 2026-02-06 22:24:43,669 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-06 22:24:43,669 INFO sqlalchemy.engine.Engine COMMIT
# ✅ Recreated data/external/cultpass.db with fresh schema

# %%
engine = create_engine(f"sqlite:///{cultpass_db}", echo=False)
cultpass.Base.metadata.create_all(engine)

# %% [markdown]
# **Experiences**

# %%
experience_data = []

with open('data/external/cultpass_experiences.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        experience_data.append(json.loads(line))

# %%
experience_data
# Out:
# [{'title': 'Carnival History Tour in Olinda',
#   'description': "Discover the origins and vibrant traditions of Pernambuco's Carnival.",
#   'location': 'Pernambuco, Brazil'},
#  {'title': 'Sunset Paddleboarding',
#   'description': 'Glide across calm waters at golden hour with all gear included.',
#   'location': 'Santa Catarina, Brazil'},
#  {'title': 'Pelourinho Colonial Walk',
#   'description': 'Wander through colorful streets and learn about Afro-Brazilian history.',
#   'location': 'Bahia, Brazil'},
#  {'title': 'Samba Night at Lapa',
#   'description': 'Dance the night away at a traditional samba club in the Lapa arches.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Christ the Redeemer Experience',
#   'description': 'Take a guided trip to one of the New Seven Wonders of the World with historical context.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Modern Art at MASP',
#   'description': 'Enjoy a guided visit to the São Paulo Museum of Art with insights into its top collections.',
#   'location': 'São Paulo, Brazil'},
#  {'title': 'Ibirapuera Park Bike Ride',
#   'description': "Cycle through the city's most iconic park with stops for photos and history.",
#   'location': 'São Paulo, Brazil'},
#  {'title': 'Guided Tour through Vienna',
#   'description': "Explore Vienna's rich history and culture with a knowledgeable local guide.",
#   'location': 'Vienna, Austria'},
#  {'title': 'Danube River Cruise',
#   'description': 'Experience the beauty of Vienna from the Danube with a relaxing river cruise.',
#   'location': 'Vienna, Austria'},
#  {'title': 'Viennese Coffeehouse Experience',
#   'description': 'Discover the traditional Viennese coffee culture with tastings and stories.',
#   'location': 'Vienna, Austria'},
#  {'title': 'Tea Ceremony in Kyoto',
#   'description': 'Participate in a traditional Japanese tea ceremony and learn about its cultural significance.',
#   'location': 'Kyoto, Japan'},
#  {'title': 'Kyoto Temple Tour',
#   'description': "Visit some of Kyoto's most famous temples and learn about their history and architecture.",
#   'location': 'Kyoto, Japan'},
#  {'title': 'Gion District Walk',
#   'description': 'Explore the historic Gion district, known for its traditional wooden machiya houses and geisha culture.',
#   'location': 'Kyoto, Japan'},
#  {'title': 'Kimono Photography Session',
#   'description': 'Dress in a traditional kimono and have a professional photoshoot in scenic Kyoto locations.',
#   'location': 'Kyoto, Japan'},
#  {'title': 'Sake Tasting Experience',
#   'description': 'Learn about the art of sake brewing and enjoy a tasting session with a sake expert.',
#   'location': 'Kyoto, Japan'},
#  {'title': 'Guided Tour through Paris',
#   'description': 'Discover the history, art, and culture of Paris with a knowledgeable local guide.',
#   'location': 'Paris, France'},
#  {'title': 'Seine River Cruise',
#   'description': 'Experience the beauty of Paris from the Seine with a relaxing river cruise.',
#   'location': 'Paris, France'},
#  {'title': 'Louvre Museum Tour',
#   'description': 'Explore the world-famous Louvre Museum with a guided tour of its top masterpieces.',
#   'location': 'Paris, France'},
#  {'title': 'Montmartre Art Walk',
#   'description': 'Stroll through the bohemian Montmartre district and learn about its artistic history.',
#   'location': 'Paris, France'},
#  {'title': 'French Pastry Workshop',
#   'description': 'Learn how to make classic French pastries in a hands-on workshop with a pastry chef.',
#   'location': 'Paris, France'},
#  {'title': 'Vatican Museums Tour',
#   'description': 'Explore the Vatican Museums and Sistine Chapel with a knowledgeable guide.',
#   'location': 'Rome, Italy'},
#  {'title': 'Colosseum Underground Tour',
#   'description': 'Discover the hidden underground chambers of the Colosseum with an expert guide.',
#   'location': 'Rome, Italy'},
#  {'title': 'Roman Forum and Palatine Hill Walk',
#   'description': 'Explore the ancient heart of Rome with a guided tour of the Roman Forum and Palatine Hill.',
#   'location': 'Rome, Italy'},
#  {'title': 'Trastevere Food Tour',
#   'description': "Experience the vibrant food scene of Rome's Trastevere neighborhood with a local guide.",
#   'location': 'Rome, Italy'},
#  {'title': 'Pasta Making Class',
#   'description': 'Learn how to make traditional Italian pasta from scratch in a hands-on cooking class.',
#   'location': 'Rome, Italy'},
#  {'title': 'Guided Tour through London',
#   'description': 'Discover the history, culture, and hidden gems of London with a knowledgeable local guide.',
#   'location': 'London, UK'},
#  {'title': 'Thames River Cruise',
#   'description': 'Experience the beauty of London from the Thames with a relaxing river cruise.',
#   'location': 'London, UK'},
#  {'title': 'British Museum Tour',
#   'description': 'Explore the world-famous British Museum with a guided tour of its top collections.',
#   'location': 'London, UK'},
#  {'title': 'West End Theatre Experience',
#   'description': "Enjoy a night out at London's West End with tickets to a popular show and insights into the theatre scene.",
#   'location': 'London, UK'},
#  {'title': 'Afternoon Tea Experience',
#   'description': 'Indulge in a traditional British afternoon tea with scones, sandwiches, and pastries at a historic venue.',
#   'location': 'London, UK'}]

# %%
with get_session(engine) as session:
    experiences = []

    for idx, experience in enumerate(experience_data):
        exp = cultpass.Experience(
            experience_id=str(uuid.uuid4())[:6],
            title=experience["title"],
            description=experience["description"],
            location=experience["location"],
            when=datetime.now() + timedelta(days=idx+1),
            slots_available=random.randint(1,30),
            is_premium=(idx % 2 == 0)
        )
        experiences.append(exp)

    session.add_all(experiences)

# %% [markdown]
# **User**

# %%
cultpass_users = []

with open('data/external/cultpass_users.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        cultpass_users.append(json.loads(line))

# %%
cultpass_users
# Out:
# [{'id': 'a4ab87',
#   'name': 'Alice Kingsley',
#   'email': 'alice.kingsley@wonderland.com',
#   'is_blocked': True},
#  {'id': 'f556c0',
#   'name': 'Bob Stone',
#   'email': 'bob.stone@granite.com',
#   'is_blocked': False},
#  {'id': '88382b',
#   'name': 'Cathy Bloom',
#   'email': 'cathy.bloom@florals.org',
#   'is_blocked': False},
#  {'id': '888fb2',
#   'name': 'David Noir',
#   'email': 'david.noir@shadowmail.com',
#   'is_blocked': True},
#  {'id': 'f1f10d',
#   'name': 'Eva Green',
#   'email': 'eva.green@ecosoul.net',
#   'is_blocked': False},
#  {'id': 'e6376d',
#   'name': 'Frank Ocean',
#   'email': 'frank.ocean@seawaves.io',
#   'is_blocked': False}]

# %%
with get_session(engine) as session:
    db_users = []
    for user_info in cultpass_users:
        user = cultpass.User(
            user_id=user_info["id"],
            full_name=user_info["name"],
            email=user_info["email"],
            is_blocked=user_info["is_blocked"],
            created_at=datetime.now()
        )
        db_users.append(user)
    session.add_all(db_users)

# %% [markdown]
# **Subscription**

# %%
with get_session(engine) as session:
    subscriptions = []
    for user_info in cultpass_users:
        subscription = cultpass.Subscription(
            subscription_id=str(uuid.uuid4())[:6],
            user_id=user_info["id"],
            status=random.choice(["active", "cancelled"]),
            tier=random.choice(["basic", "premium"]),
            monthly_quota=random.randint(2,10),
            started_at=datetime.now()
        )
        subscriptions.append(subscription)

    session.add_all(subscriptions)

# %% [markdown]
# **Reservation**

# %%
# Applicable to `cultpass_users[0]` at the moment

with get_session(engine) as session:
    experience_ids = [
        exp.experience_id 
        for exp 
        in session.query(cultpass.Experience).all()
    ]

    reservation1 = cultpass.Reservation(
        reservation_id=str(uuid.uuid4())[:6],
        user_id=cultpass_users[0]["id"],
        experience_id=random.choice(experience_ids),
        status="reserved",
    )

    reservation2 = cultpass.Reservation(
        reservation_id=str(uuid.uuid4())[:6],
        user_id=cultpass_users[0]["id"],
        experience_id=random.choice(experience_ids),
        status="reserved",
    )

    session.add_all([reservation1, reservation2])

# %%
# TODO: Add more data
# Please notice that the reservations were set to first user only 
# If you want to simulate more users later, please create more reservations per user

with get_session(engine) as session:
    pass

# %% [markdown]
# # Tests

# %%
with get_session(engine) as session:
    users = session.query(cultpass.User).all()
    for user in users:
        print(user)
# Out:
# <User(user_id='a4ab87', email='alice.kingsley@wonderland.com', is_blocked=True)>
# <User(user_id='f556c0', email='bob.stone@granite.com', is_blocked=False)>
# <User(user_id='88382b', email='cathy.bloom@florals.org', is_blocked=False)>
# <User(user_id='888fb2', email='david.noir@shadowmail.com', is_blocked=True)>
# <User(user_id='f1f10d', email='eva.green@ecosoul.net', is_blocked=False)>
# <User(user_id='e6376d', email='frank.ocean@seawaves.io', is_blocked=False)>

# %%
with get_session(engine) as session:
    users = session.query(cultpass.User).all()
    for user in users:
        print(user.subscription)
# Out:
# <Subscription(subscription_id='0ca0ec', user_id='a4ab87', status='active', tier='premium')>
# <Subscription(subscription_id='4e038c', user_id='f556c0', status='active', tier='basic')>
# <Subscription(subscription_id='12ba4f', user_id='88382b', status='cancelled', tier='basic')>
# <Subscription(subscription_id='8b801f', user_id='888fb2', status='active', tier='premium')>
# <Subscription(subscription_id='fdf3f5', user_id='f1f10d', status='cancelled', tier='basic')>
# <Subscription(subscription_id='b0665d', user_id='e6376d', status='cancelled', tier='premium')>

# %%
with get_session(engine) as session:
    experiences = session.query(cultpass.Experience).all()
    for experience in experiences:
        print(experience)
# Out:
# <Experience(experience_id='861a89', title='Carnival History Tour in Olinda', when='2026-02-07 22:24:47.485639')>
# <Experience(experience_id='298b8e', title='Sunset Paddleboarding', when='2026-02-08 22:24:47.489784')>
# <Experience(experience_id='cea8d5', title='Pelourinho Colonial Walk', when='2026-02-09 22:24:47.489840')>
# <Experience(experience_id='bd1d60', title='Samba Night at Lapa', when='2026-02-10 22:24:47.489881')>
# <Experience(experience_id='55c8db', title='Christ the Redeemer Experience', when='2026-02-11 22:24:47.489922')>
# <Experience(experience_id='024c91', title='Modern Art at MASP', when='2026-02-12 22:24:47.489964')>
# <Experience(experience_id='9f99b2', title='Ibirapuera Park Bike Ride', when='2026-02-13 22:24:47.490005')>
# <Experience(experience_id='169202', title='Guided Tour through Vienna', when='2026-02-14 22:24:47.490047')>
# <Experience(experience_id='532104', title='Danube River Cruise', when='2026-02-15 22:24:47.490090')>
# <Experience(experience_id='0bd579', title='Viennese Coffeehouse Experience', when='2026-02-16 22:24:47.490131')>
# <Experience(experience_id='ab58b3', title='Tea Ceremony in Kyoto', when='2026-02-17 22:24:47.490174')>
# <Experience(experience_id='500126', title='Kyoto Temple Tour', when='2026-02-18 22:24:47.490214')>
# <Experience(experience_id='54e308', title='Gion District Walk', when='2026-02-19 22:24:47.490254')>
# <Experience(experience_id='296651', title='Kimono Photography Session', when='2026-02-20 22:24:47.490299')>
# <Experience(experience_id='3e3cd5', title='Sake Tasting Experience', when='2026-02-21 22:24:47.490340')>
# <Experience(experience_id='05456b', title='Guided Tour through Paris', when='2026-02-22 22:24:47.490380')>
# <Experience(experience_id='b637e9', title='Seine River Cruise', when='2026-02-23 22:24:47.490421')>
# <Experience(experience_id='36225d', title='Louvre Museum Tour', when='2026-02-24 22:24:47.490461')>
# <Experience(experience_id='a8975f', title='Montmartre Art Walk', when='2026-02-25 22:24:47.490501')>
# <Experience(experience_id='4f9939', title='French Pastry Workshop', when='2026-02-26 22:24:47.490541')>
# <Experience(experience_id='ae51e3', title='Vatican Museums Tour', when='2026-02-27 22:24:47.490581')>
# <Experience(experience_id='97d660', title='Colosseum Underground Tour', when='2026-02-28 22:24:47.490621')>
# <Experience(experience_id='914c21', title='Roman Forum and Palatine Hill Walk', when='2026-03-01 22:24:47.490661')>
# <Experience(experience_id='a8dbe1', title='Trastevere Food Tour', when='2026-03-02 22:24:47.490701')>
# <Experience(experience_id='ff39e2', title='Pasta Making Class', when='2026-03-03 22:24:47.490742')>
# <Experience(experience_id='f41489', title='Guided Tour through London', when='2026-03-04 22:24:47.490782')>
# <Experience(experience_id='2f8ed3', title='Thames River Cruise', when='2026-03-05 22:24:47.490823')>
# <Experience(experience_id='31531e', title='British Museum Tour', when='2026-03-06 22:24:47.490863')>
# <Experience(experience_id='ff3897', title='West End Theatre Experience', when='2026-03-07 22:24:47.490904')>
# <Experience(experience_id='9b50ec', title='Afternoon Tea Experience', when='2026-03-08 22:24:47.490945')>
